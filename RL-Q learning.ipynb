# %% [markdown]
# Trying method 1

# %%
import numpy as np

# %%
#define the shape of the environment (i.e., its states)
environment_rows = 3
environment_columns = 3
#Create a 3D numpy array to hold the current Q-values for each state and action pair: Q(s, a) 
#The array contains 3 rows and 3 columns (to match the shape of the environment), as well as a third "action" dimension.
#The "action" dimension consists of 4 layers that will allow us to keep track of the Q-values for each possible action in
#each state (see next cell for a description of possible actions). 
#The value of each (state, action) pair is initialized to 0.
q_values = np.zeros((environment_rows, environment_columns, 4))

# %%
#define actions
#numeric action codes: 0 = up, 1 = right, 2 = down, 3 = left
actions = ['up', 'right', 'down', 'left']

# %%
#Create a 2D numpy array to hold the rewards for each state. 
#The array contains 3 rows and 3 columns (to match the shape of the environment), and each value is initialized to 
rewards = np.full((environment_rows, environment_columns), 0.)
rewards[0, 1] = 0.523 #vanilla
rewards[1, 0] = 0.400  #conditional
rewards[2, 1] = 0.515 #DCGAN
rewards[1, 2] = 0.237  #cycle
rewards[1, 1] = -1
rewards[0, 0] = -1
rewards[0, 2] = -1
rewards[2, 2] = -1
rewards[2, 0] = -1
 #set the reward for each GAN and other locations

for row in rewards:
  print(row)
# Out:
# [-1.     0.523 -1.   ]
# [ 0.4   -1.     0.237]
# [-1.     0.515 -1.   ]

# %%
#define a function that determines if the specified location is a terminal state
def is_terminal_state(current_row_index, current_column_index):
  #if the reward for this location is -1, then it is not a terminal state (i.e., it is a 'white square')
  if rewards[current_row_index, current_column_index] == -1:
    return False
  else:
    return True
#define a function that will choose a random, non-terminal starting location
def get_starting_location():
  #get a random row and column index
  current_row_index = np.random.randint(environment_rows)
  current_column_index = np.random.randint(environment_columns)
  #continue choosing random row and column indexes until a non-terminal state is identified
  #(i.e., until the chosen state is a 'white square').
  #while is_terminal_state(current_row_index, current_column_index):
   # current_row_index = np.random.randint(environment_rows)
   # current_column_index = np.random.randint(environment_columns)
  return current_row_index, current_column_index
#define an epsilon greedy algorithm that will choose which action to take next (i.e., where to move next)
def get_next_action(current_row_index, current_column_index, epsilon):
  #if a randomly chosen value between 0 and 1 is less than epsilon, 
  #then choose the most promising value from the Q-table for this state.
  if np.random.random() < epsilon:
    return np.argmax(q_values[current_row_index, current_column_index])
  else: #choose a random action
    return np.random.randint(4)

# %%
#define a function that will get the next location based on the chosen action
def get_next_location(current_row_index, current_column_index, action_index):
  new_row_index = current_row_index
  new_column_index = current_column_index
  if actions[action_index] == 'up' and current_row_index > 0:
    new_row_index -= 1
  elif actions[action_index] == 'right' and current_column_index < environment_columns - 1:
    new_column_index += 1
  elif actions[action_index] == 'down' and current_row_index < environment_rows - 1:
    new_row_index += 1
  elif actions[action_index] == 'left' and current_column_index > 0:
    new_column_index -= 1
  return new_row_index, new_column_index

# %%
ganmodels={'VanillaGAN':-1,'ConditionalGAN':-1,'DCGAN':-1,'CycleGAN':-1}
print(ganmodels)
# Out:
# {'VanillaGAN': -1, 'ConditionalGAN': -1, 'DCGAN': -1, 'CycleGAN': -1}

# %%
#define training parameters
epsilon = 0.8 #the percentage of time when we should take the best action (instead of a random action)
discount_factor = 0.75 #discount factor for future rewards
learning_rate = 0.005 #the rate at which the agent should learn
#run through 1000 training episodes
for episode in range(10000):
  #print("hello")
  #get the starting location for this episode
  row_index, column_index = get_starting_location()
  #print("\nstarting location is (", row_index," ,", column_index, ")")
  #continue taking actions (i.e., moving) until we reach a terminal state
  #(i.e., until we reach the item packaging area or crash into an item storage location)
  while not is_terminal_state(row_index, column_index):
    #print("hello")
    #choose which action to take (i.e., where to move next)
    action_index = get_next_action(row_index, column_index, epsilon)
    #perform the chosen action, and transition to the next state (i.e., move to the next location)
    old_row_index, old_column_index = row_index, column_index #store the old row and column indexes
   # print("check", old_row_index, old_column_index, row_index, column_index)
    row_index, column_index = get_next_location(row_index, column_index, action_index)
    #receive the reward for moving to the new state, and calculate the temporal difference
    reward = rewards[row_index, column_index]
    old_q_value = q_values[old_row_index, old_column_index, action_index]
    temporal_difference = reward + (discount_factor * np.max(q_values[row_index, column_index])) - old_q_value
    #update the Q-value for the previous state and action pair
    new_q_value = old_q_value + (learning_rate * temporal_difference)
    q_values[old_row_index, old_column_index, action_index] = new_q_value
    if(row_index==0 and column_index==1):
      if(new_q_value>ganmodels['VanillaGAN']):
        ganmodels['VanillaGAN']=new_q_value
    if(row_index==1 and column_index==0):
      if(new_q_value>ganmodels['ConditionalGAN']):
        ganmodels['ConditionalGAN']=new_q_value
    if(row_index==2 and column_index==1):
      if(new_q_value>ganmodels['DCGAN']):
        ganmodels['DCGAN']=new_q_value
    if(row_index==1 and column_index==2):
      if(new_q_value>ganmodels['CycleGAN']):
        ganmodels['CycleGAN']=new_q_value
    print("\nQ values for episode:", episode, "is:", new_q_value, "and choose next action:", action_index, "to go to:", row_index, column_index)
print('Training complete!')
# Out:
# Q values for episode: 8 is: 0.007013 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 15 is: 0.013990935000000001 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 17 is: 0.020933980325 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 30 is: 0.006105 and choose next action: 2 to go to: 2 1
#
# Q values for episode: 44 is: 0.027842310423375 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 48 is: 0.03471609887125813 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 55 is: 0.04155551837690184 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 63 is: 0.048360740785017335 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 65 is: 0.05513193708109225 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 69 is: 0.06186927739568679 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 75 is: 0.06857293100870836 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 82 is: 0.07524306635366482 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 89 is: 0.012179475 and choose next action: 2 to go to: 2 1
#
# Q values for episode: 110 is: 0.08187985102189649 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 122 is: 0.088483451766787 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 142 is: 0.09505403450795306 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 144 is: 0.1015917643354133 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 146 is: 0.10809680551373622 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 158 is: 0.11456932148616754 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 175 is: 0.1210094748787367 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 202 is: 0.127417427504343 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 205 is: 0.1337933403668213 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 212 is: 0.1401373736649872 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 218 is: 0.1464496867966623 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 243 is: 0.15273043836267897 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 249 is: 0.15897978617086558 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 262 is: 0.007307500000000001 and choose next action: 3 to go to: 1 0
#
# Q values for episode: 267 is: 0.16519788724001125 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 269 is: 0.018223577625 and choose next action: 2 to go to: 2 1
#
# Q values for episode: 312 is: 0.1713848978038112 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 316 is: 0.17754097331479213 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 318 is: 0.0145784625 and choose next action: 3 to go to: 1 0
#
# Q values for episode: 323 is: 0.18366626844821818 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 328 is: 0.18976093710597708 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 331 is: 0.1958251324204472 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 337 is: 0.20185900675834495 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 338 is: 0.20786271172455323 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 349 is: 0.21383639816593047 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 359 is: 0.21978021617510082 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 368 is: 0.22569431509422533 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 370 is: 0.2315788435187542 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 373 is: 0.23743394930116044 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 388 is: 0.24325977955465464 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 390 is: 0.24905648065688135 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 403 is: 0.2548241982535969 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 414 is: 0.024237459736875 and choose next action: 2 to go to: 2 1
#
# Q values for episode: 424 is: 0.2605630772623289 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 435 is: 0.26627326187601724 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 461 is: 0.27195489556663716 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 471 is: 0.27760812108880395 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 485 is: 0.28323308048335993 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 497 is: 0.28882991508094313 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 498 is: 0.2943987655055384 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 529 is: 0.2999397716780107 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 536 is: 0.3054530728196207 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 538 is: 0.3109388074555226 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 542 is: 0.030221272438190627 and choose next action: 2 to go to: 2 1
#
# Q values for episode: 551 is: 0.036175166075999673 and choose next action: 2 to go to: 2 1
#
# Q values for episode: 569 is: 0.316397113418245 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 570 is: 0.3218281278511538 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 576 is: 0.006816 and choose next action: 1 to go to: 1 2
#
# Q values for episode: 579 is: 0.327231987211898 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 583 is: 0.3326088272758385 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 607 is: 0.3379587831394593 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 616 is: 0.343281989223762 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 630 is: 0.3485785792776432 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 632 is: 0.353848686381255 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 644 is: 0.3590924429493487 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 650 is: 0.36430998073460197 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 661 is: 0.36950143083092896 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 663 is: 0.3746669236767743 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 671 is: 0.042099290245619675 and choose next action: 2 to go to: 2 1
#
# Q values for episode: 699 is: 0.37980658905839043 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 701 is: 0.3849205561130985 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 714 is: 0.390008953332533 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 715 is: 0.3950719085658703 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 727 is: 0.40010954902304097 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 736 is: 0.40512200127792575 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 751 is: 0.4101093912715361 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 761 is: 0.41507184431517846 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 765 is: 0.4200094850936026 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 768 is: 0.01359792 and choose next action: 1 to go to: 1 2
#
# Q values for episode: 773 is: 0.4249224376681346 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 775 is: 0.42981082547979393 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 787 is: 0.43467477135239496 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 806 is: 0.439514397495633 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 852 is: 0.4443298255081548 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 869 is: 0.44912117638061405 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 871 is: 0.453888570498711 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 890 is: 0.45863212764621747 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 892 is: 0.46335196700798637 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 894 is: 0.46804820717294643 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 895 is: 0.4727209661370817 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 899 is: 0.4773703613063963 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 904 is: 0.48199650949986433 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 905 is: 0.0218130701875 and choose next action: 3 to go to: 1 0
#
# Q values for episode: 908 is: 0.486599526952365 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 909 is: 0.4911795293176032 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 920 is: 0.4957366316710152 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 922 is: 0.5002709485126602 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 927 is: 0.5047825937700969 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 932 is: 0.04799379379439158 and choose next action: 2 to go to: 2 1
#
# Q values for episode: 950 is: 0.5092716808012464 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 951 is: 0.05385882482541962 and choose next action: 2 to go to: 2 1
#
# Q values for episode: 957 is: 0.5137383223972402 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 969 is: 0.518182630785254 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 974 is: 0.5226047176313277 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 983 is: 0.0203459304 and choose next action: 1 to go to: 1 2
#
# Q values for episode: 989 is: 0.527004694043171 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 990 is: 0.5313826705729551 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 996 is: 0.5357387572200903 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 997 is: 0.5400730634339899 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1006 is: 0.5443856981168199 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1018 is: 0.0290115048365625 and choose next action: 3 to go to: 1 0
#
# Q values for episode: 1022 is: 0.5486767696262358 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1027 is: 0.05969453070129252 and choose next action: 2 to go to: 2 1
#
# Q values for episode: 1050 is: 0.5529463857781046 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1073 is: 0.5571946538492141 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1090 is: 0.561421680579968 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1091 is: 0.5656275721770682 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1092 is: 0.5698124343161828 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1106 is: 0.5739763721446018 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1107 is: 0.5781194902838789 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1112 is: 0.06550105804778605 and choose next action: 2 to go to: 2 1
#
# Q values for episode: 1113 is: 0.5822418928324595 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1123 is: 0.5863436833682972 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1150 is: 0.5904249649514558 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1160 is: 0.5944858401266985 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1178 is: 0.598526410926065 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1182 is: 0.6025467788714346 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1183 is: 0.6065470449770775 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1191 is: 0.610527309752192 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1200 is: 0.03617394731237969 and choose next action: 3 to go to: 1 0
#
# Q values for episode: 1208 is: 0.6144876732034311 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1209 is: 0.6184282348374139 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1212 is: 0.6223490936632269 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1219 is: 0.6262503481949108 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1226 is: 0.6301320964539362 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1235 is: 0.6339944359716665 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1239 is: 0.6378374637918082 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1247 is: 0.6416612764728491 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1248 is: 0.07127855275754713 and choose next action: 2 to go to: 2 1
#
# Q values for episode: 1272 is: 0.6454659700904849 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1285 is: 0.6492516402400325 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1294 is: 0.6530183820388323 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1369 is: 0.6567662901286382 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1376 is: 0.04330057757581779 and choose next action: 3 to go to: 1 0
#
# Q values for episode: 1378 is: 0.660495458677995 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1390 is: 0.664205981384605 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1391 is: 0.6678979514776819 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1407 is: 0.6715714617202936 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1409 is: 0.6752266044116921 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1414 is: 0.027060200748000002 and choose next action: 1 to go to: 1 2
#
# Q values for episode: 1423 is: 0.6788634713896337 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1426 is: 0.6824821540326855 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1429 is: 0.686082743262522 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1435 is: 0.07702715999375939 and choose next action: 2 to go to: 2 1
#
# Q values for episode: 1444 is: 0.6896653295462094 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1450 is: 0.6932300028984784 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1454 is: 0.6967768528839859 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1465 is: 0.7003059686195661 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1470 is: 0.7038174387764682 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1491 is: 0.7073113515825858 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1493 is: 0.7107877948246729 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1519 is: 0.7142468558505496 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1535 is: 0.7176886215712969 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1544 is: 0.7211131784634404 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1557 is: 0.7245206125711232 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1572 is: 0.7279110095082676 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1576 is: 0.7312844544607262 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1577 is: 0.7346410321884226 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1579 is: 0.0827470241937906 and choose next action: 2 to go to: 2 1
#
# Q values for episode: 1581 is: 0.7379808270274805 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1582 is: 0.741303922892343 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1584 is: 0.7446104032778813 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1598 is: 0.7479003512614919 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1607 is: 0.7511738495051844 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1646 is: 0.7544309802576584 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1665 is: 0.7576718253563701 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1667 is: 0.0503915746879387 and choose next action: 3 to go to: 1 0
#
# Q values for episode: 1669 is: 0.7608964662295883 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1670 is: 0.7641049838984404 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1679 is: 0.7672974589789482 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1697 is: 0.7704739716840534 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1704 is: 0.7736346018256332 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1705 is: 0.776779428816505 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1712 is: 0.7799085316724225 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1716 is: 0.7830219890140604 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1719 is: 0.7861198790689901 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1733 is: 0.7892022796736451 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1757 is: 0.08843828907282164 and choose next action: 2 to go to: 2 1
#
# Q values for episode: 1759 is: 0.7922692682752769 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1760 is: 0.03374089974426 and choose next action: 1 to go to: 1 2
#
# Q values for episode: 1779 is: 0.7953209219339005 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1798 is: 0.798357317324231 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1807 is: 0.05744711681449901 and choose next action: 3 to go to: 1 0
#
# Q values for episode: 1815 is: 0.8013785307376098 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1827 is: 0.8043846380839217 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1838 is: 0.8073757148935021 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1843 is: 0.8103518363190346 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1845 is: 0.8133130771374395 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1855 is: 0.8162595117517523 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1862 is: 0.8191912141929935 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1866 is: 0.09410109762745754 and choose next action: 2 to go to: 2 1
#
# Q values for episode: 1867 is: 0.8221082581220285 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1884 is: 0.040388195245538695 and choose next action: 1 to go to: 1 2
#
# Q values for episode: 1887 is: 0.8250107168314184 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1893 is: 0.8278986632472612 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1912 is: 0.830772169931025 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1924 is: 0.047002254269311004 and choose next action: 1 to go to: 1 2
#
# Q values for episode: 1926 is: 0.8336313090813698 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1960 is: 0.836476152535963 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 1973 is: 0.06446738123042652 and choose next action: 3 to go to: 1 0
#
# Q values for episode: 1990 is: 0.8393067717732832 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2006 is: 0.8421232379144168 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2011 is: 0.8449256217248448 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2019 is: 0.8477139936162206 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2026 is: 0.8504884236481395 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2030 is: 0.8532489815298988 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2036 is: 0.07145254432427438 and choose next action: 3 to go to: 1 0
#
# Q values for episode: 2037 is: 0.8559957366222494 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2039 is: 0.8587287579391382 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2043 is: 0.8614481141494424 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2053 is: 0.8641538735786952 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2056 is: 0.8668461042108018 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2083 is: 0.8695248736897477 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2084 is: 0.872190249321299 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2093 is: 0.8748422980746925 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2096 is: 0.877481086584319 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2099 is: 0.8801066811513975 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2105 is: 0.8827191477456404 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2109 is: 0.8853185520069122 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2117 is: 0.8879049592468776 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2123 is: 0.8904784344506432 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2126 is: 0.05358324299796445 and choose next action: 1 to go to: 1 2
#
# Q values for episode: 2141 is: 0.89303904227839 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2142 is: 0.8955868470669981 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2143 is: 0.06013132678297463 and choose next action: 1 to go to: 1 2
#
# Q values for episode: 2146 is: 0.8981219128316631 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2162 is: 0.9006443032675048 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2177 is: 0.9031540817511673 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2181 is: 0.9056513113424115 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2182 is: 0.9081360547856995 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2185 is: 0.910608374511771 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2186 is: 0.09973559213932025 and choose next action: 2 to go to: 2 1
#
# Q values for episode: 2202 is: 0.9130683326392122 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2208 is: 0.9155159909760161 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2212 is: 0.917951411021136 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2229 is: 0.9203746539660302 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2237 is: 0.9227857806962001 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2238 is: 0.9251848517927191 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2261 is: 0.9275719275337555 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2267 is: 0.9299470678960867 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2268 is: 0.9323103325566063 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2279 is: 0.9346617808938233 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2291 is: 0.9370014719893542 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2298 is: 0.9393294646294075 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2304 is: 0.9416458173062604 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2312 is: 0.9439505882197291 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2316 is: 0.9462438352786304 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2339 is: 0.9485256161022373 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2344 is: 0.9507959880217262 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2373 is: 0.9530550080816175 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2375 is: 0.06664667014905976 and choose next action: 1 to go to: 1 2
#
# Q values for episode: 2376 is: 0.9553027330412094 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2377 is: 0.9575392193760034 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2383 is: 0.07312943679831446 and choose next action: 1 to go to: 1 2
#
# Q values for episode: 2394 is: 0.9597645232791234 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2397 is: 0.9619787006627278 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2406 is: 0.10534191417862365 and choose next action: 2 to go to: 2 1
#
# Q values for episode: 2414 is: 0.9641818071594142 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2417 is: 0.078402781602653 and choose next action: 3 to go to: 1 0
#
# Q values for episode: 2435 is: 0.9663738981236171 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2439 is: 0.968555028632999 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2441 is: 0.9707252534898341 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2447 is: 0.9728846272223849 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2450 is: 0.9750332040862729 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2453 is: 0.9771710380658416 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2469 is: 0.9792981828755124 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2479 is: 0.9814146919611348 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2484 is: 0.9835206185013292 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2487 is: 0.9856160154088226 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2490 is: 0.9877009353317785 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2511 is: 0.9897754306551196 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2515 is: 0.991839553501844 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2519 is: 0.9938933557343348 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2538 is: 0.9959368889556631 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2581 is: 0.9979702045108848 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2590 is: 0.9999933534883304 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2615 is: 1.0020063867208888 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2619 is: 1.0040093547872844 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2629 is: 1.006002308013348 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2651 is: 0.0795797896143229 and choose next action: 1 to go to: 1 2
#
# Q values for episode: 2652 is: 1.0079852964732812 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2663 is: 1.0099583699909147 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2674 is: 1.01192157814096 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2676 is: 1.0138749702502552 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2689 is: 1.015818595399004 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2690 is: 1.0177525024220089 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2699 is: 1.019676739909899 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2700 is: 1.0215913562103494 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2712 is: 1.0234963994292976 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2717 is: 1.025391917432151 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2732 is: 1.0272779578449904 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2733 is: 1.0291545680557654 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2748 is: 0.08531826769463974 and choose next action: 3 to go to: 1 0
#
# Q values for episode: 2757 is: 1.0310217952154865 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2760 is: 1.0328796862394092 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2776 is: 1.0347282878082122 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2795 is: 1.036567646369171 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2803 is: 1.0383978081373253 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2815 is: 1.0402188190966386 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2816 is: 0.09219917635616653 and choose next action: 3 to go to: 1 0
#
# Q values for episode: 2818 is: 1.0420307250011553 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2821 is: 1.0438335713761495 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2828 is: 1.0456274035192687 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2845 is: 1.0474122665016723 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2848 is: 1.049188205169164 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2881 is: 1.050955264143318 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2892 is: 1.0527134878226014 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2907 is: 1.0544629203834883 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2908 is: 1.056203605781571 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2910 is: 1.057935587752663 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2920 is: 0.11092020460773054 and choose next action: 2 to go to: 2 1
#
# Q values for episode: 2924 is: 1.0596589098138998 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2930 is: 1.0613736152648303 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2939 is: 1.063079747188506 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2945 is: 1.0647773484525636 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2946 is: 1.0664664617103008 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2953 is: 1.0681471294017493 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2970 is: 1.0698193937547404 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2971 is: 0.11647060358469188 and choose next action: 2 to go to: 2 1
#
# Q values for episode: 2973 is: 0.09904568047438571 and choose next action: 3 to go to: 1 0
#
# Q values for episode: 2978 is: 1.0714832967859667 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2983 is: 1.0731388803020367 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2987 is: 1.0747861859005265 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2990 is: 1.0764252549710238 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2994 is: 1.0780561286961687 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2996 is: 1.079678848052688 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 2998 is: 1.0812934538124246 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3002 is: 0.08599789066625128 and choose next action: 1 to go to: 1 2
#
# Q values for episode: 3009 is: 0.10585795207201378 and choose next action: 3 to go to: 1 0
#
# Q values for episode: 3013 is: 1.0828999865433624 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3021 is: 0.09238390121292003 and choose next action: 1 to go to: 1 2
#
# Q values for episode: 3037 is: 1.0844984866106455 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3039 is: 1.0860889941775922 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3041 is: 1.0876715492067042 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3064 is: 1.0892461914606706 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3071 is: 1.0908129605033672 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3080 is: 1.0923718957008504 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3095 is: 0.1126361623116537 and choose next action: 3 to go to: 1 0
#
# Q values for episode: 3102 is: 1.0939230362223462 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3110 is: 1.0954664210412344 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3113 is: 1.0970020889360281 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3116 is: 1.098530078491348 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3120 is: 1.1000504280988914 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3132 is: 1.101563175958397 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3141 is: 1.103068360078605 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3151 is: 0.11938048150009543 and choose next action: 3 to go to: 1 0
#
# Q values for episode: 3153 is: 1.104566018278212 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3158 is: 0.12609107909259495 and choose next action: 3 to go to: 1 0
#
# Q values for episode: 3166 is: 1.106056188186821 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3172 is: 0.09873798170685544 and choose next action: 1 to go to: 1 2
#
# Q values for episode: 3175 is: 1.1075389072458868 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3188 is: 1.1090142127096574 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3193 is: 1.110482141646109 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3200 is: 1.1119427309378784 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3201 is: 1.113396017283189 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3215 is: 1.1148420371967729 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3269 is: 1.1162808270107891 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3287 is: 1.1177124228757351 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3308 is: 1.1191368607613565 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3313 is: 1.1205541764575497 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3316 is: 1.121964405575262 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3319 is: 1.1233675835473858 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3334 is: 1.1247637456296489 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3344 is: 1.1261529269015007 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3352 is: 1.1275351622669931 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3361 is: 1.128910486455658 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3369 is: 1.1302789340233799 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3380 is: 0.10506029179832116 and choose next action: 1 to go to: 1 2
#
# Q values for episode: 3382 is: 1.131640539353263 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3387 is: 1.1329953366564967 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3398 is: 1.1343433599732142 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3404 is: 1.135684643173348 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3406 is: 1.1370192199574813 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3408 is: 1.1383471238576939 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3413 is: 1.1396683882384053 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3415 is: 1.1409830462972133 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3417 is: 1.142291131065727 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3426 is: 0.11135099033932955 and choose next action: 1 to go to: 1 2
#
# Q values for episode: 3428 is: 1.1435926754103984 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3429 is: 1.1448877120333465 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3436 is: 1.1461762734731797 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3443 is: 1.147458392105814 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3453 is: 0.1176102353876329 and choose next action: 1 to go to: 1 2
#
# Q values for episode: 3457 is: 1.1487341001452849 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3470 is: 1.1500034296445585 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3485 is: 0.13276812369713198 and choose next action: 3 to go to: 1 0
#
# Q values for episode: 3489 is: 1.1512664124963357 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3497 is: 0.13941178307864632 and choose next action: 3 to go to: 1 0
#
# Q values for episode: 3498 is: 1.152523080433854 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3501 is: 1.1537734650316847 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3519 is: 1.1550175977065262 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3533 is: 1.1562555097179936 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3546 is: 1.1574872321694036 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3547 is: 1.1587127960085566 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3551 is: 1.1599322320285137 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3552 is: 0.14602222416325308 and choose next action: 3 to go to: 1 0
#
# Q values for episode: 3558 is: 0.12199325056676842 and choose next action: 2 to go to: 2 1
#
# Q values for episode: 3565 is: 1.1611455708683711 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3569 is: 1.1623528430140293 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3578 is: 1.1635540787989591 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3579 is: 1.1647493084049643 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3605 is: 1.1659385618629394 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3609 is: 1.1671218690536247 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3613 is: 1.1682992597083566 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3614 is: 1.1694707634098147 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3623 is: 1.1706364095927657 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3630 is: 1.171796227544802 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3631 is: 1.172950246407078 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3654 is: 1.1740984951750426 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3655 is: 1.1752410026991673 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3675 is: 1.1763777976856715 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3689 is: 1.1775089086972432 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3699 is: 1.178634364153757 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3711 is: 1.1797541923329884 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3716 is: 1.1808684213713234 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3733 is: 1.1819770792644668 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3739 is: 0.12383818421069474 and choose next action: 1 to go to: 1 2
#
# Q values for episode: 3752 is: 1.1830801938681446 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3762 is: 0.15259961304243683 and choose next action: 3 to go to: 1 0
#
# Q values for episode: 3771 is: 1.1841777928988038 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3779 is: 1.1852699039343098 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3810 is: 1.1863565544146382 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3817 is: 1.187437771642565 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3825 is: 1.1885135827843523 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3838 is: 1.1895840148704304 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3850 is: 0.13003499328964127 and choose next action: 1 to go to: 1 2
#
# Q values for episode: 3854 is: 1.1906490947960782 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3870 is: 1.1917088493220978 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3875 is: 0.13620081832319306 and choose next action: 1 to go to: 1 2
#
# Q values for episode: 3887 is: 1.1927633050754873 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3907 is: 1.1938124885501098 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3916 is: 0.15914411497722464 and choose next action: 3 to go to: 1 0
#
# Q values for episode: 3918 is: 1.1948564261073593 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3919 is: 0.1423358142315771 and choose next action: 1 to go to: 1 2
#
# Q values for episode: 3920 is: 1.1958951439768226 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3927 is: 0.12748828431393458 and choose next action: 2 to go to: 2 1
#
# Q values for episode: 3929 is: 1.1969286682569384 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3947 is: 1.1979570249156537 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3966 is: 1.1989802397910754 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3972 is: 1.19999833859212 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3975 is: 1.2010113468991594 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 3978 is: 1.2020192901646636 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4005 is: 1.2030221937138403 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4006 is: 1.2040200827452712 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4010 is: 0.16565589440233852 and choose next action: 3 to go to: 1 0
#
# Q values for episode: 4017 is: 1.2050129823315447 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4023 is: 1.2060009174198871 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4033 is: 1.2069839128327877 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4041 is: 1.2079619932686239 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4042 is: 0.17213511493032682 and choose next action: 3 to go to: 1 0
#
# Q values for episode: 4050 is: 1.2089351833022808 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4052 is: 1.2099035073857694 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4077 is: 0.1484401351604192 and choose next action: 1 to go to: 1 2
#
# Q values for episode: 4081 is: 1.2108669898488404 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4087 is: 1.2118256548995963 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4088 is: 1.2127795266250982 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4100 is: 1.2137286289919726 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4103 is: 1.2146729858470129 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4104 is: 0.17858193935567518 and choose next action: 3 to go to: 1 0
#
# Q values for episode: 4106 is: 1.2156126209177778 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4113 is: 1.2165475578131888 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4116 is: 1.2174778200241227 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4120 is: 1.2184034309240022 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4127 is: 0.1329558428923649 and choose next action: 2 to go to: 2 1
#
# Q values for episode: 4133 is: 1.2193244137693822 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4146 is: 1.2202407917005353 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4178 is: 1.2211525877420326 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4180 is: 1.2220598248033225 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4186 is: 1.222962525679306 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4224 is: 1.2238607130509094 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4226 is: 0.1849965296588968 and choose next action: 3 to go to: 1 0
#
# Q values for episode: 4230 is: 1.2247544094856548 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4231 is: 1.2256436374382265 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4264 is: 1.2265284192510353 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4268 is: 1.2274087771547801 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4272 is: 1.2282847332690063 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4281 is: 1.2291563096026612 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4293 is: 1.2300235280546479 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4332 is: 1.2308864104143746 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4352 is: 1.2317449783623027 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4377 is: 1.2325992534704913 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4383 is: 1.2334492572031388 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4393 is: 1.2342950109171231 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4395 is: 1.2351365358625375 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4425 is: 1.2359738531832247 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4427 is: 1.2368069839173086 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4429 is: 0.15451393448461712 and choose next action: 1 to go to: 1 2
#
# Q values for episode: 4432 is: 1.237635948997722 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4440 is: 1.2384607692527334 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4463 is: 0.19137904701060232 and choose next action: 3 to go to: 1 0
#
# Q values for episode: 4485 is: 1.2392814654064697 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4514 is: 1.2400980580794374 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4520 is: 1.2409105677890402 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4524 is: 1.241719014950095 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4526 is: 0.1977296517755493 and choose next action: 3 to go to: 1 0
#
# Q values for episode: 4531 is: 1.2425234198753445 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4538 is: 1.2433238027759679 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4554 is: 1.244120183762088 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4556 is: 1.2449125828432777 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4558 is: 1.2457010199290612 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4562 is: 1.2464855148294158 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4580 is: 1.2472660872552688 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4587 is: 1.2480427568189925 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4597 is: 1.2488155430348975 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4604 is: 1.249584465319723 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4605 is: 1.2503495429931244 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4608 is: 1.2511107952781588 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4636 is: 1.251868241301768 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4639 is: 0.16055736481219404 and choose next action: 1 to go to: 1 2
#
# Q values for episode: 4666 is: 1.2526219000952592 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4669 is: 1.253371790594783 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4683 is: 1.2541179316418092 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4697 is: 1.2548603419836002 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4698 is: 1.2555990402736823 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4700 is: 1.256334045072314 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 4706 is: 0.16657057798813307 and choose next action: 1 to go to: 1 2
#
# ...
#
# Q values for episode: 8285 is: 1.3733347545948718 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8287 is: 1.3734810808218973 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8289 is: 1.373626675417788 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8316 is: 0.28071648384310693 and choose next action: 1 to go to: 1 2
#
# Q values for episode: 8323 is: 1.373771542040699 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8325 is: 1.3739156843304956 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8328 is: 1.3740591059088432 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8336 is: 1.374201810379299 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8338 is: 0.2655251431253614 and choose next action: 3 to go to: 1 0
#
# Q values for episode: 8340 is: 1.3743438013274025 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8343 is: 1.3744850823207655 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8362 is: 1.3746256569091617 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8385 is: 0.21176400316286412 and choose next action: 2 to go to: 2 1
#
# Q values for episode: 8393 is: 1.3747655286246159 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8402 is: 1.3749047009814928 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8405 is: 1.3750431774765852 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8419 is: 1.3751809615892023 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8434 is: 1.3753180567812564 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8435 is: 1.37545446649735 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8440 is: 1.3755901941648634 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8444 is: 1.375725243194039 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8445 is: 1.3758596169780688 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8453 is: 0.2168101831470498 and choose next action: 2 to go to: 2 1
#
# Q values for episode: 8461 is: 1.3759933188931786 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8469 is: 1.3761263522987126 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8497 is: 1.376258720537219 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8525 is: 1.3763904269345328 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8530 is: 0.2715050174097346 and choose next action: 3 to go to: 1 0
#
# Q values for episode: 8532 is: 0.27745499232268594 and choose next action: 3 to go to: 1 0
#
# Q values for episode: 8533 is: 1.3765214747998602 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8542 is: 1.376651867425861 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8543 is: 1.3767816080887316 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8558 is: 1.3769107000482879 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8559 is: 1.3770391465480465 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8587 is: 1.3771669508153062 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8589 is: 1.3772941160612295 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8610 is: 0.2861289014238914 and choose next action: 1 to go to: 1 2
#
# Q values for episode: 8612 is: 1.3774206454809235 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8627 is: 1.377546542253519 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8628 is: 1.3776718095422513 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8639 is: 0.29151425691677196 and choose next action: 1 to go to: 1 2
#
# Q values for episode: 8642 is: 1.3777964504945401 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8660 is: 1.3779204682420674 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8663 is: 1.3780438659008571 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8672 is: 1.378166646571353 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8684 is: 1.378288813338496 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8709 is: 1.3784103692718035 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8716 is: 1.3785313174254445 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8717 is: 1.3786516608383172 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8724 is: 1.3787714025341256 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8730 is: 1.3788905455214548 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8736 is: 1.3790090927938476 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8738 is: 1.3791270473298785 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8745 is: 1.379244412093229 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8757 is: 0.2833752173610725 and choose next action: 3 to go to: 1 0
#
# Q values for episode: 8758 is: 1.379361190032763 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8772 is: 1.3794773840825991 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8782 is: 1.379592997162186 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8801 is: 1.379708032176375 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8812 is: 1.3798224920154931 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8829 is: 1.3799363795554156 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8857 is: 1.3800496976576384 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8866 is: 1.3801624491693503 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8890 is: 1.3802746369235035 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8892 is: 1.380386263738886 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8906 is: 1.3804973324201915 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8916 is: 1.3806078457580906 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8929 is: 1.3807178065293002 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8946 is: 1.3808272174966536 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8947 is: 1.3809360814091702 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8962 is: 1.3810444010021243 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8964 is: 1.3811521789971137 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8969 is: 1.3812594181021283 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8972 is: 1.3813661210116177 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 8978 is: 1.3814722904065597 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9004 is: 1.381577928954527 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9020 is: 1.3816830393097543 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9045 is: 1.3817876241132057 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9047 is: 1.3818916859926396 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9048 is: 1.3819952275626763 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9080 is: 1.382098251424863 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9083 is: 1.3822007601677386 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9093 is: 1.3823027563669 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9101 is: 0.28926584127426713 and choose next action: 3 to go to: 1 0
#
# Q values for episode: 9124 is: 0.2951270120678958 and choose next action: 3 to go to: 1 0
#
# Q values for episode: 9125 is: 1.3824042425850653 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9136 is: 1.38250522137214 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9139 is: 0.30095887700755636 and choose next action: 3 to go to: 1 0
#
# Q values for episode: 9142 is: 1.3826056952652794 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9158 is: 0.30676158262251857 and choose next action: 3 to go to: 1 0
#
# Q values for episode: 9159 is: 1.382705666788953 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9170 is: 1.3828051384550082 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9173 is: 1.382904112762733 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9175 is: 1.3830025921989193 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9186 is: 1.3831005792379247 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9206 is: 0.31253527470940595 and choose next action: 3 to go to: 1 0
#
# Q values for episode: 9207 is: 0.3182800983358589 and choose next action: 3 to go to: 1 0
#
# Q values for episode: 9226 is: 0.2968726856321881 and choose next action: 1 to go to: 1 2
#
# Q values for episode: 9231 is: 1.383198076341735 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9259 is: 0.22183113223131457 and choose next action: 2 to go to: 2 1
#
# Q values for episode: 9260 is: 1.3832950859600264 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9276 is: 1.3833916105302262 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9300 is: 1.383487652477575 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9308 is: 0.226826976570158 and choose next action: 2 to go to: 2 1
#
# Q values for episode: 9317 is: 0.30220432220402715 and choose next action: 1 to go to: 1 2
#
# Q values for episode: 9318 is: 0.2317978416873072 and choose next action: 2 to go to: 2 1
#
# Q values for episode: 9333 is: 1.3835832142151872 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9335 is: 0.23674385247887064 and choose next action: 2 to go to: 2 1
#
# Q values for episode: 9336 is: 1.3836782981441111 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9340 is: 0.24166513321647629 and choose next action: 2 to go to: 2 1
#
# Q values for episode: 9348 is: 1.3837729066533906 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9356 is: 1.3838670421201236 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9358 is: 0.3239961978441796 and choose next action: 3 to go to: 1 0
#
# Q values for episode: 9372 is: 1.383960706909523 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9403 is: 1.3840539033749755 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9425 is: 1.3841466338581006 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9431 is: 1.38423890068881 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9439 is: 1.384330706185366 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9440 is: 1.3844220526544393 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9442 is: 0.3296837168549587 and choose next action: 3 to go to: 1 0
#
# Q values for episode: 9450 is: 1.384512942391167 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9457 is: 1.3846033776792113 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9473 is: 1.3846933607908152 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9477 is: 1.3847828939868612 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9507 is: 1.3848719795169269 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9516 is: 1.3849606196193422 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9526 is: 0.2465618075503939 and choose next action: 2 to go to: 2 1
#
# Q values for episode: 9533 is: 1.3850488165212456 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9545 is: 1.3851365724386393 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9549 is: 1.3852238895764462 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9562 is: 1.3853107701285639 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9563 is: 1.3853972162779211 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9589 is: 1.3854832301965314 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9591 is: 1.3855688140455487 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9596 is: 1.385653969975321 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9598 is: 1.3857387001254444 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9602 is: 1.3858230066248172 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9608 is: 1.385906891591693 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9613 is: 1.3859903571337346 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9615 is: 1.386073405348066 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9647 is: 1.3861560383213256 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9654 is: 1.386238258129719 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9662 is: 1.3863200668390705 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9673 is: 1.3864014665048752 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9676 is: 0.33534279827068386 and choose next action: 3 to go to: 1 0
#
# Q values for episode: 9684 is: 0.2514339985126419 and choose next action: 2 to go to: 2 1
#
# Q values for episode: 9691 is: 1.3864824591723508 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9692 is: 1.3865630468764891 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9700 is: 1.3866432316421067 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9714 is: 1.386723015483896 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9719 is: 1.3868024004064765 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9723 is: 1.3868813884044442 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9728 is: 0.34097358427933044 and choose next action: 3 to go to: 1 0
#
# Q values for episode: 9732 is: 0.2562818285200787 and choose next action: 2 to go to: 2 1
#
# Q values for episode: 9742 is: 1.386959981462422 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9746 is: 1.38703818155511 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9758 is: 0.2611054193774783 and choose next action: 2 to go to: 2 1
#
# Q values for episode: 9760 is: 1.3871159906473345 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9799 is: 1.3871934106940977 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9815 is: 1.3872704436406273 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9816 is: 1.3873470914224242 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9833 is: 1.387423355965312 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9872 is: 1.3874992391854855 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9874 is: 1.387574742989558 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9899 is: 0.2659048922805909 and choose next action: 2 to go to: 2 1
#
# Q values for episode: 9903 is: 1.3876498692746102 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9936 is: 1.3877246199282371 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9956 is: 0.2706803678191879 and choose next action: 2 to go to: 2 1
#
# Q values for episode: 9960 is: 1.387798996828596 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9966 is: 0.3465762163579338 and choose next action: 3 to go to: 1 0
#
# Q values for episode: 9969 is: 1.387873001844453 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9978 is: 1.3879466368352307 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9983 is: 1.3880199036510545 and choose next action: 0 to go to: 0 1
#
# Q values for episode: 9989 is: 0.307509300593007 and choose next action: 1 to go to: 1 2
#
# Q values for episode: 9992 is: 1.3880928041327993 and choose next action: 0 to go to: 0 1
# Training complete!

# %%
print(ganmodels)
# Out:
# {'VanillaGAN': 1.3880928041327993, 'ConditionalGAN': 0.3465762163579338, 'DCGAN': 0.2706803678191879, 'CycleGAN': 0.307509300593007}
